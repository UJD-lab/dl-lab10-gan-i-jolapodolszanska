# %% [markdown]
# # Sztuczne sieci neuronowe i głębokie uczenie - Sprawozdanie z laboratorium
#
# ## Temat:
#
# Wpisz temat ćwiczenia (z instrukcji dołączonej do laboratorium)
#
# ### Cel ćwiczenia:
#
# Tu wpisz cel ćwiczenia
#
# ### Wykorzystane narzędzia:
#
# Tu wpisz wykorzystane narzędzia np. Colab, Python z wersjami bibliotek

# %% [markdown]
# ### Wykres gęstości rozkładu normalnego
#
# Tu opisz przebieg ćwiczenia

# %%
# tu wklej swój kod

# %% [markdown]
# ### Wykres funkcji f(x) = x^3
#
# Tu opisz przebieg ćwiczenia

# %%
# tu wklej swój kod

# %% [markdown]
# ### Wnioski
#
# Tu wypisz wnioski z ćwiczeń z laboratorium
